# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from utils.dataloader import DataLoader

import warnings

warnings.filterwarnings("ignore")
FOLDER_PATH = 'C:\\Users\\gogan\\source\\repos\\pet-project\\pet-project\\data'

# %%
all_data = pd.read_csv('drug200.csv')
train = pd.read_csv(FOLDER_PATH + '//train.csv')
val = pd.read_csv(FOLDER_PATH + '//val.csv')

# %%
loader = DataLoader()

loader.fit(all_data)
X, Y = loader.load_data()

loader.fit(train)
X_train, Y_train = loader.load_data()

loader.fit(val)
X_valid, Y_valid = loader.load_data()

# %%
from sklearn.decomposition import PCA

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  200 non-null    int32
#  1   Sex                  200 non-null    int32
#  2   BP                   200 non-null    int32
#  3   Cholesterol          200 non-null    int32
#  4   Na_to_K              200 non-null    float64
#  5   Na_to_K_categorical  200 non-null    int32
# dtypes: float64(1), int32(5)
# memory usage: 5.6 KB

# %%
pca = PCA(n_components=2)
t = pca.fit_transform(X)
plt.figure(figsize=(10, 10))
x = t[:, :1].reshape(t.shape[0])
y = t[:, 1:].reshape(t.shape[0])
plt.scatter(x, y, c=Y)
plt.show()

# %%
plt.hist(Y)
plt.show()

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(X.corr(), fignum=f.number)
plt.xticks(range(X.select_dtypes(['number']).shape[1]), X.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(X.select_dtypes(['number']).shape[1]), X.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
X.head()
# Out:
#    Age  Sex  BP  Cholesterol  Na_to_K  Na_to_K_categorical
# 0    0    0   0            0   25.355                    1
# 1    2    1   1            0   13.093                    0
# 2    2    1   1            0   10.114                    0
# 3    0    0   2            0    7.798                    0
# 4    3    0   1            0   18.043                    0

# %%
sns.barplot(X['Na_to_K_categorical'], Y)
plt.show()

# %%
sns.barplot(X['Cholesterol'], Y)
plt.show()

# %%
sns.barplot(X['Age'], Y)
plt.show()

# %%
sns.barplot(X['Sex'], Y)
plt.show()

# %%
sns.barplot(X['BP'], Y)
plt.show()

# %%
sns.distplot(X['Na_to_K'])
plt.show()

# %%
sns.jointplot(X['Na_to_K'], Y, kind='kde')
plt.show()

# %%
sns.jointplot(X['Na_to_K'], Y, kind='hex')
plt.show()

# %%
data = X.copy()
data['target'] = Y
sns.pairplot(data[['target', 'BP', 'Na_to_K', 'Cholesterol']])
plt.show()

# %%
sns.stripplot(X['Age'], Y)
plt.show()

# %%
sns.stripplot(X['Sex'], Y)
plt.show()

# %%
sns.stripplot(X['Na_to_K_categorical'], Y)
plt.show()

# %%
sns.stripplot(X['Cholesterol'], Y)
plt.show()

# %%
sns.stripplot(X['BP'], Y)
plt.show()
